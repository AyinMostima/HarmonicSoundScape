# %%
from sqlalchemy import create_engine,inspect
import pandas as pd
from sqlalchemy import text
import psycopg2 
import numpy as np
import seaborn as sns

# %%
engine = create_engine(
    'postgresql+psycopg2://postgres:123456@111.186.56.196:5432/postgres',
    isolation_level="AUTOCOMMIT"
)

# %%
# 使用SQLAlchemy的inspect模块获取表和列信息
inspector = inspect(engine)

# 获取所有表的名称
tables = inspector.get_table_names()

# 遍历每个表并获取列名称
for table in tables:
    columns = inspector.get_columns(table)
    column_names = [column['name'] for column in columns]
    print(f"Table '{table}' has columns: {column_names}")
# Out:
# Table 'audio_data' has columns: ['Date', 'file_x', 'ZCR', 'MEANt', 'VARt', 'SKEWt', 'KURTt', 'LEQt', 'BGNt', 'SNRt', 'MED', 'Ht', 'ACTtFraction', 'ACTtCount', 'ACTtMean', 'EVNtFraction', 'EVNtMean', 'EVNtCount', 'MEANf', 'VARf', 'SKEWf', 'KURTf', 'NBPEAKS', 'LEQf', 'ENRf', 'BGNf', 'SNRf', 'Hf', 'EAS', 'ECU', 'ECV', 'EPS', 'EPS_KURT', 'EPS_SKEW', 'ACI', 'NDSI', 'rBA', 'AnthroEnergy', 'BioEnergy', 'BI', 'ROU', 'ADI', 'AEI', 'LFC', 'MFC', 'HFC', 'ACTspFract', 'ACTspCount', 'ACTspMean', 'EVNspFract', 'EVNspMean', 'EVNspCount', 'TFSD', 'H_Havrda', 'H_Renyi', 'H_pairedShannon', 'H_gamma', 'H_GiniSimpson', 'RAOQ', 'AGI', 'ROItotal', 'ROIcover', 'file_name', 'bird_1', 'confidence_1', 'bird_2', 'confidence_2', 'bird_3', 'confidence_3', 'bird_4', 'confidence_4', 'bird_5', 'confidence_5', 'Chords', 'Key', 'Tempo_Estimates', 'Onsets', 'file_y', 'frequencies', 'LTS', 'MEANt_per_bin', 'VARt_per_bin', 'SKEWt_per_bin', 'KURTt_per_bin', 'LEQf_per_bin', 'ENRf_per_bin', 'BGNf_per_bin', 'SNRf_per_bin', 
# ...

# %%
def query_database(columns, table_name, engine):
    # 构建 SQL 查询语句
    column_str = ', '.join([f'"{col}"' for col in columns])  # 处理 SQL 列名
    db_type = engine.dialect.name  # 获取数据库类型
    order_by_clause = "ORDER BY RANDOM()" if db_type in ["sqlite", "postgresql"] else "ORDER BY RAND()"

    query = text(f'SELECT {column_str} FROM {table_name} {order_by_clause} LIMIT 100')

    # 执行查询并加载数据到 DataFrame
    try:
        df = pd.read_sql_query(query, con=engine)
        return df
    except Exception as e:
        print("Error in query execution:", e)
        return None
# 指定查询列
columns = ['file', 'realfilename', 'foldername', 'birdenname', 'birdspgen', 'Date', 'gen', 'sp', 'ssp', 'group', 'en', 'rec', 'cnt', 'loc', 'lat', 'lng', 'alt', 'type', 'sex', 'stage', 'method', 'url', 'file_dataset', 'file-name', 'sono', 'osci', 'lic', 'q', 'length', 'time', 'date', 'uploaded', 'also', 'rmk', 'bird-seen', 'animal-seen', 'playback-used', 'temp', 'regnr', 'auto', 'dvc', 'mic', 'smp', 'fullfilename', 'Date_dataset', 'filewithpath', 'ZCR', 'MEANt', 'VARt', 'SKEWt', 'KURTt', 'LEQt', 'BGNt', 'SNRt', 'MED', 'Ht', 'ACTtFraction', 'ACTtCount', 'ACTtMean', 'EVNtFraction', 'EVNtMean', 'EVNtCount', 'MEANf', 'VARf', 'SKEWf', 'KURTf', 'NBPEAKS', 'LEQf', 'ENRf', 'BGNf', 'SNRf', 'Hf', 'EAS', 'ECU', 'ECV', 'EPS', 'EPS_KURT', 'EPS_SKEW', 'ACI', 'NDSI', 'rBA', 'AnthroEnergy', 'BioEnergy', 'BI', 'ROU', 'ADI', 'AEI', 'LFC', 'MFC', 'HFC', 'ACTspFract', 'ACTspCount', 'ACTspMean', 'EVNspFract', 'EVNspMean', 'EVNspCount', 'TFSD', 'H_Havrda', 'H_Renyi', 'H_pairedShannon', 'H_gamma', 'H_GiniSimpson', 'RAOQ', 'AGI', 'ROItotal', 'ROIcover', 'bird_1', 'confidence_1', 'bird_2', 'confidence_2', 'bird_3', 'confidence_3', 'bird_4', 'confidence_4', 'bird_5', 'confidence_5', 'Key', 'Tempo_Estimates', 'Onsets', 'chordhmm', 'chroma', 'chord', 'chordtime', 'file_name', 'frequencies', 'LTS', 'MEANt_per_bin', 'VARt_per_bin', 'SKEWt_per_bin', 'KURTt_per_bin', 'LEQf_per_bin', 'ENRf_per_bin', 'BGNf_per_bin', 'SNRf_per_bin', 'Ht_per_bin', 'ACI_per_bin', 'ROU_per_bin', 'ACTspFract_per_bin', 'ACTspCount_per_bin', 'EVNspFract_per_bin', 'EVNspMean_per_bin', 'EVNspCount_per_bin', 'AGI_per_bin', 'isclipped', 'ismusic', 'isspeech', 'class_1', 'confidence_voice_1', 'class_2', 'confidence_voice_2', 'class_3', 'confidence_voice_3', 'class_4', 'confidence_voice_4', 'class_5', 'confidence_voice_5', 'class_6', 'confidence_voice_6', 'class_7', 'confidence_voice_7', 'class_8', 'confidence_voice_8', 'class_9', 'confidence_voice_9', 'class_10', 'confidence_voice_10', 'process']
# 查询数据
df_sample = query_database(columns, "audioglobal1", engine)
df_sample
# Out:
#             file realfilename                           foldername  \
# 0   XC767544.mp3     XC767544       Cygnus columbianus_Tundra Swan
# 1   XC829355.mp3     XC829355  Numenius phaeopus_Eurasian Whimbrel
# 2   XC774250.mp3     XC774250            Anas crecca_Eurasian Teal
# 3   XC730489.mp3     XC730489            Fulica atra_Eurasian Coot
# 4   XC635298.mp3     XC635298   Gallinula chloropus_Common Moorhen
# ..           ...          ...                                  ...
# 95  XC605756.mp3     XC605756           Anas platyrhynchos_Mallard
# 96  XC803083.mp3     XC803083            Anas crecca_Eurasian Teal
# 97  XC698774.mp3     XC698774            Anas crecca_Eurasian Teal
# 98  XC570753.mp3     XC570753   Gallinula chloropus_Common Moorhen
# 99  XC554304.mp3     XC554304   Gallinula chloropus_Common Moorhen
#
#            birdenname            birdspgen                Date        gen  \
# 0         Tundra Swan   Cygnus columbianus 2022-12-08 04:44:00     Cygnus
# ...

# %%
def query_database(columns, table_name, engine):
    # 构建 SQL 查询
    column_str = ', '.join([f'"{col}"' for col in columns])
    query = f'SELECT {column_str} FROM {table_name}'
    

    # 执行查询并加载数据到 DataFrame
    try:
        df = pd.read_sql_query(text(query), con=engine)
        return df
    except Exception as e:
        print("Error in query execution:", e)
        return None

# %%
# 定义 SQL 查询，确保列名大小写正确
columns = ['Date', 'birdenname', 'birdspgen','file', 'realfilename','rec', 'cnt', 'loc', 'lat', 'lng','also','q','type']
table_name = "audioglobal1"
# 使用 pandas 的 read_sql_query 函数直接加载数据到 DataFrame
df = query_database(columns, table_name, engine)
df.to_pickle('fileinformation.pkl')

# %%
# 定义 SQL 查询，确保列名大小写正确
columns = ['Date', 'birdenname', 'birdspgen','file', 'realfilename','rec', 'cnt', 'loc', 'lat', 'lng','also','q','type','ZCR', 'MEANt', 'VARt', 'SKEWt', 'KURTt', 'LEQt', 'BGNt', 'SNRt', 'MED', 'Ht', 'ACTtFraction', 'ACTtCount', 'ACTtMean', 'EVNtFraction', 'EVNtMean', 'EVNtCount', 'MEANf', 'VARf', 'SKEWf', 'KURTf', 'NBPEAKS', 'LEQf', 'ENRf', 'BGNf', 'SNRf', 'Hf', 'EAS', 'ECU', 'ECV', 'EPS', 'EPS_KURT', 'EPS_SKEW', 'ACI', 'NDSI', 'rBA', 'AnthroEnergy', 'BioEnergy', 'BI', 'ROU', 'ADI', 'AEI', 'LFC', 'MFC', 'HFC', 'ACTspFract', 'ACTspCount', 'ACTspMean', 'EVNspFract', 'EVNspMean', 'EVNspCount', 'TFSD', 'H_Havrda', 'H_Renyi', 'H_pairedShannon', 'H_gamma', 'H_GiniSimpson', 'RAOQ', 'AGI', 'ROItotal', 'ROIcover']
table_name = "audioglobal1"
# 使用 pandas 的 read_sql_query 函数直接加载数据到 DataFrame
df = query_database(columns, table_name, engine)

# %%
df.to_pickle('soundfeature_other.pkl')

# %%
# 定义 SQL 查询，确保列名大小写正确
columns = ['Date', 'birdenname', 'birdspgen','file', 'realfilename','rec', 'cnt', 'loc', 'lat', 'lng','also','q','type', 'chord', 'chordtime','Key']
table_name = "audioglobal1"
# 使用 pandas 的 read_sql_query 函数直接加载数据到 DataFrame
df = query_database(columns, table_name, engine)

# %%
df.to_pickle('music_var_chordkey.pkl')

# %%
# 定义 SQL 查询，确保列名大小写正确
columns = ['Date', 'birdenname', 'birdspgen','file', 'realfilename','rec', 'cnt', 'loc', 'lat', 'lng','also','q','type','Tempo_Estimates', 'Onsets']
table_name = "audioglobal1"
# 使用 pandas 的 read_sql_query 函数直接加载数据到 DataFrame
df = query_database(columns, table_name, engine)

# %%
df.to_pickle('music_var_tempo.pkl')

# %%
# 定义 SQL 查询，确保列名大小写正确
columns = ['Date', 'birdenname', 'birdspgen','file', 'realfilename','rec', 'cnt', 'loc', 'lat', 'lng','also','q','type','bird_1', 'confidence_1', 'bird_2', 'confidence_2', 'bird_3', 'confidence_3', 'bird_4', 'confidence_4', 'bird_5', 'confidence_5','class_1', 'confidence_voice_1', 'class_2', 'confidence_voice_2', 'class_3', 'confidence_voice_3', 'class_4', 'confidence_voice_4', 'class_5', 'confidence_voice_5', 'class_6', 'confidence_voice_6', 'class_7', 'confidence_voice_7', 'class_8', 'confidence_voice_8', 'class_9', 'confidence_voice_9', 'class_10', 'confidence_voice_10']
table_name = "audioglobal1"
# 使用 pandas 的 read_sql_query 函数直接加载数据到 DataFrame
df = query_database(columns, table_name, engine)

# %%
df.to_pickle('class_var.pkl')

# %%
# 定义 SQL 查询，确保列名大小写正确
columns = ['Date', 'birdenname', 'birdspgen','file', 'realfilename','rec', 'cnt', 'loc', 'lat', 'lng','also','q','type','NDSI', 'ADI', 'ACI', 'RAOQ','AnthroEnergy','rBA','BioEnergy','BI','AEI','H_pairedShannon']
table_name = "audioglobal1"
# 使用 pandas 的 read_sql_query 函数直接加载数据到 DataFrame
df = query_database(columns, table_name, engine)

# %%
df.to_pickle('basic_var.pkl')

# %%
df
# Out:
#                      Date                   birdenname        birdspgen  \
# 0     2022-01-16 00:00:00                Eurasian Teal      Anas crecca
# 1     2023-12-13 10:03:00                Eurasian Teal      Anas crecca
# 2     2024-11-04 08:11:00                Eurasian Teal      Anas crecca
# 3     2014-07-13 09:00:00                Eurasian Teal      Anas crecca
# 4     2023-12-18 15:03:00                Eurasian Teal      Anas crecca
# ...                   ...                          ...              ...
# 14620 2020-10-04 21:05:00  Greater White-fronted Goose  Anser albifrons
# 14621 2022-10-02 22:00:00  Greater White-fronted Goose  Anser albifrons
# 14622 2008-02-17 19:05:00  Greater White-fronted Goose  Anser albifrons
# 14623 2021-11-23 01:36:00  Greater White-fronted Goose  Anser albifrons
# 14624 2020-11-04 01:39:00  Greater White-fronted Goose  Anser albifrons
#
#                file realfilename                    rec                 cnt  \
# ...

# %%
pd.read_pickle("basic_var.pkl").to_csv("basic_var.csv")
pd.read_pickle("class_var.pkl").to_csv("class_var.csv")
pd.read_pickle("music_var_tempo.pkl").to_csv("music_var_tempo.csv")
pd.read_pickle("soundfeature_other.pkl").to_csv("soundfeature_other.csv")
pd.read_pickle("music_var_chordkey.pkl").to_csv("music_var_chordkey.csv")
